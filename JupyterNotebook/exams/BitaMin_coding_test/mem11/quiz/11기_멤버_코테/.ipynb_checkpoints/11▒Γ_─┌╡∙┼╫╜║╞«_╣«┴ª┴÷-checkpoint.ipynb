# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %% [markdown]
# # 문제 1 - 20점

# %% [markdown]
# ### 문제 [1-1]  - 3점
#
# ### 2023년 1월 29일, 자신의 이름, MBTI, 핸드폰 번호 뒷자리를 리스트로 저장하고 그것을 Series의 형태로 변환하여 출력하세요.

# %% [markdown]
# <출력 예시>
#
# ![1-1.png](data:image/png;base64,...)

# %%
a = ['2023-01-29','홍길동','ESFP','0123']
b = pd.Series(a)
b
# Out:
# 0    2023-01-29
# 1           홍길동
# 2          ESFP
# 3          0123
# dtype: object

# %% [markdown]
# ### 문제 [1-2] - 3점
#
#
# ### 딕셔너리를 사용하여 다음의 DataFrame 모양을 만들어 출력하세요.(DataFrame은 df로 저장해주세요)

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.39.50.png](data:image/png;base64,...)

# %%
df = pd.DataFrame({'국어':[95,85,80],'수학':[100,85,90],'영어':[90,90,80],'탐구':[80,100,90]},index=['사람1','사람2','사람3'])
df
# Out:
#      국어   수학  영어   탐구
# 사람1  95  100  90   80
# 사람2  85   85  90  100
# 사람3  80   90  80   90

# %% [markdown]
# ### 문제 [1-3] - 3점
#
# ### 위에서 만들어진 df에서 '탐구'열(column)을 삭제하고 출력하세요.

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.42.55.png](data:image/png;base64,...)

# %%
# df.drop(axis = 1, columns=['탐구'],inplace=True)
df
# Out:
#      국어   수학  영어   탐구
# 사람1  95  100  90   80
# 사람2  85   85  90  100
# 사람3  80   90  80   90

# %% [markdown]
# ### 문제 [1-4] - 4점
#
# ### df에 국어, 수학, 영어 3과목의 평균 점수를 나타내는 '평균' 열(column)을 추가하여 출력하세요.(소수점 세번째 자리에서 반올림하여 소수점 둘째자리까지만 나타내세요)

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.43.12.png](data:image/png;base64,...)

# %%
df.apply(lambda x:x.mean(),axis=1)
# Out:
# 사람1    91.25
# 사람2    90.00
# 사람3    85.00
# dtype: float64

# %%
df['평균'] = df.apply(lambda x:round(x.mean(),2),axis=1)
df
# Out:
#      국어   수학  영어   탐구     평균
# 사람1  95  100  90   80  91.25
# 사람2  85   85  90  100  90.00
# 사람3  80   90  80   90  85.00

# %% [markdown]
# ### 문제 [1-5] - 7점
#
# ### '평균'열에 나온 점수를 기준으로 등급으로 변환한 '등급'열을 추가하여 출력하세요(95점 이상 A+, 90점 이상 A, 85점 이상 B+, 80점 이상 B 입니다.)

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.43.22.png](data:image/png;base64,...)

# %%
def grade(avg):
    if avg >= 95:
        return 'A+'
    elif avg>=90:
        return 'A'
    elif avg>=85:
        return 'B+'
    else:
        return 'B'
df['등급'] = df['평균'].apply(grade)
df
# Out:
#      국어   수학  영어   탐구     평균  등급
# 사람1  95  100  90   80  91.25   A
# 사람2  85   85  90  100  90.00   A
# 사람3  80   90  80   90  85.00  B+

# %% [markdown]
# # 문제 2 - 25점

# %% [markdown]
# ### 문제 [2-1] - 3점
#
# ### spotify.csv 파일을 불러오고 data 변수에 저장하여 맨 위에 3개 행을 출력하세요.

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.45.50.png](data:image/png;base64,...)

# %%
data_file = './spotify.csv'
data = pd.read_csv(data_file)
data.head(3)
# Out:
#   Country  Rank                Track_id     Streams        Track Name  \
# 0  global   1.0  25sgk305KZfyuqVBQIahim  1166185736  Sweet but Psycho
# 1  global   2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787           bad guy
# 2  global   3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044           7 rings
#
#           Artist                                                URL  \
# 0        Ava Max  https://open.spotify.com/track/25sgk305KZfyuqV...
# 1  Billie Eilish  https://open.spotify.com/track/2Fxmhks0bxGSBdJ...
# 2  Ariana Grande  https://open.spotify.com/track/6ocbgoVGwYJhOv1...
#
#    acousticness  danceability  energy  ...  valence    tempo  time_signature  \
# 0        0.0691         0.719   0.704  ...    0.628  133.002               4
# 1        0.3280         0.701   0.425  ...    0.562  135.128               4
# 2        0.5920         0.778   0.317  ...    0.327  140.048               4
#
#    duration_ms  key  mode               Artist_id  Artist_popularity  \
# ...

# %% [markdown]
# ### 문제 [2-2] - 3점
#
# ### data의 열(column) 중에서 'Artist'열에서 고유값의 종류와 갯수를 확인할 수 있는 함수를 사용하여,  다음과 같이 출력하세요.

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.46.03.png](data:image/png;base64,...)

# %%
data.columns
# Out:
# Index(['Country', 'Rank', 'Track_id', 'Streams', 'Track Name', 'Artist', 'URL',
#        'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'valence', 'tempo',
#        'time_signature', 'duration_ms', 'key', 'mode', 'Artist_id',
#        'Artist_popularity', 'Artist_follower', 'Artist_img'],
#       dtype='object')

# %%
data.loc[:,'Artist'].value_counts()
# Out:
# Post Malone      45
# Juice WRLD       31
# Ariana Grande    28
# Billie Eilish    27
# Taylor Swift     27
#                  ..
# Leona Lewis       1
# Kylie Minogue     1
# Omar Montes       1
# Paloma Mami       1
# Bee Gees          1
# Name: Artist, Length: 488, dtype: int64

# %% [markdown]
# ### 문제 [2-3] - 5점
#
# ### 'Artist'열에서 아티스트가 BTS인 행들을 찾아 출력하세요.

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.46.21.png](data:image/png;base64,...)

# %%
data_bts=data.loc[data['Artist']=='BTS']

# %% [markdown]
# ### 문제 [2-4] - 7점
#
# ### 'tempo' 열에 대한 히스토그램을 그려주세요.
# #### (구간은 총 10개로 나누고 그림 사이즈는 (10,5)로 설정하여 나타내어 주세요)

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.46.35.png](data:image/png;base64,...)

# %%
rank_size=(data.tempo.max()-data.tempo.min())/10
ranks = []
# Out:
#         index  tempo
# 0     179.974      5
# 1     153.848      4
# 2     136.041      4
# 3      90.036      4
# 4     100.003      4
# ...       ...    ...
# 1528  128.983      1
# 1529   90.076      1
# 1530  204.077      1
# 1531  163.862      1
# 1532  104.022      1
#
# [1533 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.hist(data.tempo)
# Out:
# (array([  5.,  93., 250., 361., 297., 282., 185., 135.,  81.,  28.]),
#  array([ 46.489 ,  62.5877,  78.6864,  94.7851, 110.8838, 126.9825,
#         143.0812, 159.1799, 175.2786, 191.3773, 207.476 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 문제 [2-5] - 7점
#
# ### 'Artist'가 BTS이면서 'Tempo'가 평균 이상인 것들을 다음과 같이 출력하세요.
# #### (열(column)은 Rank, Track Name, Artist, tempo만 나오도록 하세요)

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.46.48.png](data:image/png;base64,...)

# %%
tempo_mean = data_bts['tempo'].mean()
data_bts.loc[data['tempo']>=tempo_mean,['Rank','Track Name','Artist','tempo']]
# Out:
#       Rank                                         Track Name Artist    tempo
# 676  677.0                                        Mikrokosmos    BTS  174.039
# 678  679.0  Dream Glow (BTS World Original Soundtrack) - P...    BTS  141.948
# 710  711.0                                               HOME    BTS  142.991
# 725  726.0                                           Dionysus    BTS  176.084

# %% [markdown]
# # 문제 3 - 20점

# %% [markdown]
# ### (아래 코드를 실행시켜 df1 변수에 저장 후, 시작해주세요)

# %%
df1 =pd.DataFrame({'Class': ['IoT','Network', 'Economy','Big Data', 'Cloud'],
                       'Year': [2018, 2017, 2018, 2018, 2019],
                       'Price': [100, 125, 132, 312, 250],
                       'limitStudent': [40, 40, 40, 40, 40],
                       'Location': ['Korea','Korea', 'Korea', 'US','Korea']},
                      index=['C01','C02','C03', 'C04', 'C05'])
df1
# Out:
#         Class  Year  Price  limitStudent Location
# C01       IoT  2018    100            40    Korea
# C02   Network  2017    125            40    Korea
# C03   Economy  2018    132            40    Korea
# C04  Big Data  2018    312            40       US
# C05     Cloud  2019    250            40    Korea

# %% [markdown]
# ### 문제 [3-1] - 2점
#
# ### C02, C03 강의의 Class, Year 열(column)을 출력하세요.

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.52.34.png](data:image/png;base64,...)

# %%
df1.loc[['C02','C03'],['Class','Year']]
# Out:
#        Class  Year
# C02  Network  2017
# C03  Economy  2018

# %% [markdown]
# ### 문제 [3-2] - 3점
#
# ### Year 열(column)에서 년도가 2018년도 혹은 2019년도에 개설된 Class 를 출력하세요.

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.52.48.png](data:image/png;base64,...)

# %%
df1.loc[(df1['Year']==2018) | (df1['Year']==2019) , 'Class']
# Out:
# C01         IoT
# C03     Economy
# C04    Big Data
# C05       Cloud
# Name: Class, dtype: object

# %% [markdown]
# ### 문제 [3-3] - 5점
#
# ### 강의 별 price 에 대한 세로형 막대 그래프를 출력하세요.

# %%
df1.head()
# Out:
#         Class  Year  Price  limitStudent Location priceLevel
# C01       IoT  2018    100            40    Korea        Low
# C02   Network  2017    125            40    Korea        Low
# C03   Economy  2018    132            40    Korea        Low
# C04  Big Data  2018    312            40       US       High
# C05     Cloud  2019    250            40    Korea       High

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.53.01.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
plt.bar(df1.index,df1['Price'])
plt.xticks(rotation=90)
plt.xlabel('X',rotation=90)
# Out:
# Text(0.5, 0, 'X')

# %%
import matplotlib.pyplot as plt

weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
          80, 59, 67, 81, 69, 73, 69, 74, 70, 65]

plt.hist(weight, label='bins=10',color='green')
plt.hist(weight, bins=30, label='bins=30',color='yellow')
plt.legend()
plt.show()

# %% [markdown]
# ### 문제 [3-4] - 10점
#
# ### priceLevel 열(column)을 추가하고 Price 열(column)의 값이 200보다 크거나 같으면 'High', 200 보다 작으면 'Low'를 할당하여 출력하세요.
# ### 이 때, get_priceLevel() 함수를 생성하여 priceLevel열의 값들을 추가하세요.

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.53.13.png](data:image/png;base64,...)

# %%
def get_priceLevel(price):
    if price >= 200:
        return 'High'
    else:
        return 'Low'
df1['priceLevel']=df1['Price'].apply(get_priceLevel)
df1
# Out:
#         Class  Year  Price  limitStudent Location priceLevel
# C01       IoT  2018    100            40    Korea        Low
# C02   Network  2017    125            40    Korea        Low
# C03   Economy  2018    132            40    Korea        Low
# C04  Big Data  2018    312            40       US       High
# C05     Cloud  2019    250            40    Korea       High

# %% [markdown]
# # 문제4 - 20점

# %% [markdown]
# ### 문제 [4-1] - 2점
# ### titanic.csv 를 titanic 변수에 저장하여 불러와주세요.

# %%
titanic = pd.read_csv('./titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 변수설명
#
# * Survived :  (0 : No, 1 : Yes) - 범주형
# * pclass : Passenger Class (1=1st, 2=2nd, 3= 3rd) - 범주형
# * Name
# * Sex : 성별 -범주형
# * Age : 나이
# * SibSp : 동반한 배우자 / 형제 자매 수 - 수치형
# * Parch : 부모 / 자식 수 - 수치형
# * Ticket : 티켓번호 - 수치형
# * fare : 승선 요금 - 수치형
# * Cabin : 객실번호
# * Embarked : 승선 항구 이름 (C = Chenbourg , Q = Queenstown, S = Southampton)

# %% [markdown]
# ### 문제 [4-2] - 2점
#
# ### 결측값을 확인하세요.

# %%
print(len(titanic))
titanic.describe()
# Age컬럼에 결측값이 있음.
# Out:
# 891
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### 문제 [4-3] - 4점
#
# ### 변수 Ticket, Cabin을 제거하세요.

# %%
titanic.drop(axis=1,columns=['Ticket','Cabin'],inplace=True)

# %% [markdown]
# ### 문제 [4-4] - 6점
#
# ### age 변수의 결측값을 중간값으로 채워넣으세요.

# %%
age_median=titanic['Age'].median()
titanic.loc[titanic['Age'].isnull(),'Age'] = age_median
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Age'].update(age_median)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  28.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 문제 [4-5] - 6점
#
# ### 'Embarked' 변수의 결측값을  'S'로 채워넣으세요.

# %%
titanic.loc[titanic['Embarked'].isnull(),'Embarked'] = 'S' 
titanic.loc[titanic['Name']=='Icard, Miss. Amelie']
# Out:
#     PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 61           62         1       1  Icard, Miss. Amelie  female  38.0      0
#
#     Parch  Fare Embarked
# 61      0  80.0        S

# %% [markdown]
# # 문제 5 - 15점

# %% [markdown]
# ### 문제 [5-1] - 3점
#
# ### 인구수예제.xlsx를 data_p로 불러온 후, 위에서부터 5행을 출력하세요.

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.53.30.png](data:image/png;base64,...)

# %%
data_p = pd.read_excel('./└╬▒╕╝÷┐╣┴ª.xlsx')
data_p.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17132\1767621340.py in <module>
# ----> 1 data_p = pd.read_excel('./└╬▒╕╝÷┐╣┴ª.xlsx')
#       2 data_p.head()
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %% [markdown]
# ### 문제 [5-2] - 5점
#
# ### 연도별/도시별 총인구수를 구하세요.

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.53.43.png](data:image/png;base64,...)

# %% [markdown]
# ### 문제 [5-3] - 7점
#
# ### 도시/자치구별 평균 남자인구수와 여자인구수를 구하세요.

# %% [markdown]
# <출력예시>
#
# ![스크린샷 2023-01-29 오전 11.53.53.png](data:image/png;base64,...)

# %% [markdown]
# ## 코딩 테스트 보느라 고생 많으셨습니다 :)   코딩 테스트가 절대적인 평가기준은 아닙니다.
