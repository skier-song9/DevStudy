# %% [markdown]
# # 1. Matplotlib
#
# 다양한 형태의 그래프를 통해서 데이터 시각화를 도와주는 라이브러리

# %%
import matplotlib.pyplot as plt
# ⚠️ 기본 설정
import matplotlib
matplotlib.rcParams['font.family'] = "Malgun Gothic" # Windows
# matplotlib.rcParams['font.family'] = "AppleGothic" # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False #한글 사용 시, 마이너스 부호가 깨지는 현상 해결

# %% [markdown]
# # 1. 그래프 기본
#
# ### plt.plot(x축, y축) : 선 그래프를 그린다

# %%
x = [1,2,3]
y = [2,4,8]
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show() # 객체 메모리 주소 보기 싫으면 plt.show()하면 그래프만 출력한다.

# %% [markdown]
# ## 그래프의 Title 설정
#
# ### plt.title('제목')

# %%
plt.plot(x,y)
plt.title('Line Graph')
plt.show()

# %% [markdown]
# ## ⚠️한글 인코딩 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = "Malgun Gothic" # Windows
# matplotlib.rcParams['font.family'] = "AppleGothic" # Mac

# %%
matplotlib.rcParams['font.size'] = 15 # 글자 크기

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist #사용 가능한 폰트 목록 출력
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans Mono',
#  'cmtt10',
#  'STIXSizeTwoSym',
#  'STIXNonUnicode',
#  'DejaVu Serif Display',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'cmr10',
#  'DejaVu Sans Display',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'cmb10',
#  'STIXGeneral',
#  'cmss10',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'cmsy10',
#  'STIXGeneral',
#  'cmex10',
#  'DejaVu Sans',
#  'STIXSizeFiveSym',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'cmmi10',
#  'MingLiU-ExtB',
#  'Juice ITC',
#  'Informal Roman',
#  'Matura MT Script Capitals',
#  'Segoe UI',
#  'Dubai',
#  'Candara',
#  'Lucida Sans Typewriter',
#  'Cascadia Code',
#  'Arial',
#  'Franklin Gothic Heavy',
#  'Cambria',
#  'Trebuchet MS',
# ...

# %%
plt.plot(x,y)
plt.title("꺾은선 그래프")
plt.show()

# %% [markdown]
# ## ⚠️ 음수값 설정

# %%
matplotlib.rcParams['axes.unicode_minus'] = False #한글 사용 시, 마이너스 부호가 깨지는 현상 해결

# %%
plt.plot([-1,0,1],[-5,-1,2])
plt.show()
