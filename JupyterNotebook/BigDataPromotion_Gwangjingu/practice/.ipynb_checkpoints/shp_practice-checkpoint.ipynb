# %%
import gc
import glob
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## .shp 파일 읽기

# %%
file_path = "./data/National_Entertainment_Establishment_Information/ETO_38_20221206_G_001.shp"
zip_path = glob.glob("./data/National_Entertainment_Establishment_Information//ETO_38_20221206_G_001.zip")

# %%
gdf = gpd.GeoDataFrame.from_file(file_path,encoding='utf-8')
gdf.head(3)
# Out:
#    seq     zip               lnno_adres                  rdnmadr rn_zip  \
# 0  869  660040       경상남도 진주시 봉곡동 487-7    경상남도 진주시 창렬로 68 (봉곡동)  52664
# 1  399  638803  경상남도 고성군 고성읍 동외리 288-15  경상남도 고성군 고성읍 동외로 163-11  52942
# 2  439  660803      경상남도 진주시 상대동 180-30   경상남도 진주시 대신로 305 (상대동)  52774
#
#   entrprs_nm       la       lo                    geometry
# 0         이월  35.1946  128.070  POINT (128.06956 35.19458)
# 1        해운대  34.9756  128.325  POINT (128.32547 34.97562)
# 2         힐링  35.1878  128.117  POINT (128.11667 35.18777)

# %% [markdown]
# ### 지도 shp 파일 column
#
# geometry컬럼에 POLYGON(숫자,숫자,숫자,숫자)를 사용하여 지도를 그릴 수 있다.

# %%
kr_admin_district_file_path = "./data/korea_admin_districts/Dong/emd.shp"
kr_admin_district = gpd.read_file(kr_admin_district_file_path,encoding="CP949")
kr_admin_district.head(3)
# Out:
#      EMD_CD      EMD_ENG_NM EMD_KOR_NM  \
# 0  11110101   Cheongun-dong        청운동
# 1  11110102     Singyo-dong        신교동
# 2  11110103  Gungjeong-dong        궁정동
#
#                                             geometry
# 0  POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1  POLYGON ((953233.465 1953996.984, 953235.183 1...
# 2  POLYGON ((953560.228 1954257.466, 953561.190 1...

# %%
gwangjingu_list = ["군자동","능동","화양동", "구의동", "광장동","광진동", "자양동", "중곡동"]
gwangjingu = kr_admin_district[kr_admin_district['EMD_KOR_NM'].isin(gwangjingu_list)]

# %%
gwangjingu
# Out:
#         EMD_CD      EMD_ENG_NM EMD_KOR_NM  \
# 214   11215101    Junggok-dong        중곡동
# 215   11215102      Neung-dong         능동
# 216   11215103       Guui-dong        구의동
# 217   11215104  Gwangjang-dong        광장동
# 218   11215105     Jayang-dong        자양동
# 219   11215107    Hwayang-dong        화양동
# 220   11215109      Gunja-dong        군자동
# 1231  30110111     Jayang-dong        자양동
# 1883  41390128      Gunja-dong        군자동
# 2099  41590118      Neung-dong         능동
# 3563  46130109      Gunja-dong        군자동
#
#                                                geometry
# 214   POLYGON ((964825.058 1952633.250, 964875.565 1...
# 215   POLYGON ((963696.309 1950486.709, 963707.766 1...
# 216   POLYGON ((962857.614 1949472.322, 962867.514 1...
# 217   POLYGON ((965895.926 1951078.721, 965879.493 1...
# 218   POLYGON ((962325.558 1948937.413, 962383.020 1...
# 219   POLYGON ((962857.614 1949472.322, 962852.002 1...
# 220   POLYGON ((962412.658 1949833.640, 962412.375 1...
# 1231  POLYGON ((995828.854 1816421.192, 995842.817 1...
# 1883  POLYGON ((938279.303 1930197.485, 938285.240 1...
# 2099  POLYGON ((960906.208 1911317.755, 960906.550 1...
# 3563  POLYGON ((1021337.657 1639083.052, 1021339.939...

# %%
plt.rcParams["font.family"] = "NanumGothic"
plt.rcParams["figure.figsize"] = (10,10)

# %%
ax = gwangjingu.convex_hull.plot(color="green",edgecolor="w")
ax.set_title("광진구 - 읍면동")
ax.set_axis_off() # 축제거
plt.show()

# %%
kr_admin_district_file_path = "./data/korea_admin_districts/SiGunGu/sig.shp"
kr_admin_district = gpd.read_file(kr_admin_district_file_path,encoding="CP949")
kr_admin_district.head(3)
# Out:
#   SIG_CD  SIG_ENG_NM SIG_KOR_NM  \
# 0  11110   Jongno-gu        종로구
# 1  11140     Jung-gu         중구
# 2  11170  Yongsan-gu        용산구
#
#                                             geometry
# 0  POLYGON ((956615.453 1953567.199, 956621.579 1...
# 1  POLYGON ((957890.386 1952616.746, 957909.908 1...
# 2  POLYGON ((953115.761 1950834.084, 953114.206 1...

# %%
gwangjingu = kr_admin_district[kr_admin_district['SIG_KOR_NM']=="광진구"]
gwangjingu
# Out:
#   SIG_CD   SIG_ENG_NM SIG_KOR_NM  \
# 4  11215  Gwangjin-gu        광진구
#
#                                             geometry
# 4  POLYGON ((964825.058 1952633.250, 964875.565 1...

# %%
ax = gwangjingu.convex_hull.plot(color="green",edgecolor="w")
ax.set_title("광진구")
ax.set_axis_off() # 축제거
plt.show()

# %%
from shapely.geometry import Polygon

# 위도, 경도 좌표 리스트
coordinates = [(37.498205, 127.02758), (37.498205, 127.03758), (37.488205, 127.03758), (37.488205, 127.02758)]

# Polygon 객체 생성
polygon = Polygon(coordinates)

# 면적 계산
area = polygon.area
print(area)
# Out:
# 0.00010000000000003127

# %%
import matplotlib.pyplot as plt

# 위도, 경도 좌표 리스트
coordinates = [(37.498205, 127.02758), (37.498205, 127.03758), (37.488205, 127.03758), (37.488205, 127.02758)]

# 위도와 경도를 분리합니다.
lats, lons = zip(*coordinates)

# 좌표를 시각화합니다.
plt.figure()
plt.plot(lons, lats)
plt.show()

# %%
import random
from shapely.geometry import MultiPoint
import geopandas as gpd

# 무작위 위도, 경도 좌표 생성
coordinates = [(37.498205, 127.02758), (37.498205, 127.03758), (37.488205, 127.03758), (37.488205, 127.02758),
              (38.498205, 128.02758), (38.498205, 128.03758), (38.488205, 128.03758)]

# 다각형 생성
convex_hull = MultiPoint(coordinates).convex_hull

# 면적 계산
area = convex_hull.area

# 다각형 시각화
gdf = gpd.GeoDataFrame(index=[0], crs='EPSG:4326', geometry=[convex_hull])
gdf.plot()

# 위도와 경도를 분리합니다.
lats, lons = zip(*coordinates)

# 좌표를 시각화합니다.
plt.figure()
plt.plot(lons, lats)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13492\309337312.py in <module>
#      15 # 다각형 시각화
#      16 gdf = gpd.GeoDataFrame(index=[0], crs='EPSG:4326', geometry=[convex_hull])
# ---> 17 gdf.plot()
#      18
#      19 # 위도와 경도를 분리합니다.
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\geopandas\plotting.py in __call__(self, *args, **kwargs)
#     923             kind = kwargs.pop("kind", "geo")
#     924             if kind == "geo":
# --> 925                 return plot_dataframe(data, *args, **kwargs)
#     926             if kind in self._pandas_kinds:
#     927                 # Access pandas plots
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\geopandas\plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     695             markersize=markersize,
#     696             aspect=aspect,
# --> 697             **style_kwds,
#     698         )
#     699
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\geopandas\plotting.py in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     465         )
#     466
# --> 467     plt.draw()
#     468     return ax
#     469
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\pyplot.py in draw()
#     969     the current figure.
#     970     """
# --> 971     gcf().canvas.draw_idle()
#     972
#     973
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2058         if not self._is_idle_drawing:
#    2059             with self._idle_draw_cntx():
# -> 2060                 self.draw(*args, **kwargs)
#    2061
#    2062     @property
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2829             return
#    2830
# -> 2831         artists = self._get_draw_artists(renderer)
#    2832
#    2833         try:
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\figure.py in _get_draw_artists(self, renderer)
#     236                 ax.apply_aspect(pos)
#     237             else:
# --> 238                 ax.apply_aspect()
#     239
#     240             for child in ax.get_children():
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\axes\_base.py in apply_aspect(self, position)
#    1893             box_aspect = aspect * self.get_data_ratio()
#    1894             pb = position.frozen()
# -> 1895             pb1 = pb.shrunk_to_aspect(box_aspect, pb, fig_aspect)
#    1896             self._set_position(pb1.anchored(self.get_anchor(), pb), 'active')
#    1897             return
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\transforms.py in shrunk_to_aspect(self, box_aspect, container, fig_aspect)
#     556         """
#     557         if box_aspect <= 0 or fig_aspect <= 0:
# --> 558             raise ValueError("'box_aspect' and 'fig_aspect' must be positive")
#     559         if container is None:
#     560             container = self
#
# ValueError: 'box_aspect' and 'fig_aspect' must be positive
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x00000271B04E91F8> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     135     def post_execute():
#     136         if matplotlib.is_interactive():
# --> 137             draw_all()
#     138
#     139     try:  # IPython >= 2
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     139         for manager in cls.get_all_fig_managers():
#     140             if force or manager.canvas.figure.stale:
# --> 141                 manager.canvas.draw_idle()
#     142
#     143
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2058         if not self._is_idle_drawing:
#    2059             with self._idle_draw_cntx():
# -> 2060                 self.draw(*args, **kwargs)
#    2061
#    2062     @property
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2829             return
#    2830
# -> 2831         artists = self._get_draw_artists(renderer)
#    2832
#    2833         try:
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\figure.py in _get_draw_artists(self, renderer)
#     236                 ax.apply_aspect(pos)
#     237             else:
# --> 238                 ax.apply_aspect()
#     239
#     240             for child in ax.get_children():
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\axes\_base.py in apply_aspect(self, position)
#    1893             box_aspect = aspect * self.get_data_ratio()
#    1894             pb = position.frozen()
# -> 1895             pb1 = pb.shrunk_to_aspect(box_aspect, pb, fig_aspect)
#    1896             self._set_position(pb1.anchored(self.get_anchor(), pb), 'active')
#    1897             return
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\transforms.py in shrunk_to_aspect(self, box_aspect, container, fig_aspect)
#     556         """
#     557         if box_aspect <= 0 or fig_aspect <= 0:
# --> 558             raise ValueError("'box_aspect' and 'fig_aspect' must be positive")
#     559         if container is None:
#     560             container = self
#
# ValueError: 'box_aspect' and 'fig_aspect' must be positive
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\ITConsulting\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295                     self.figure.draw(renderer)
#    2296
#    2297             if bbox_inches:
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2829             return
#    2830
# -> 2831         artists = self._get_draw_artists(renderer)
#    2832
#    2833         try:
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\figure.py in _get_draw_artists(self, renderer)
#     236                 ax.apply_aspect(pos)
#     237             else:
# --> 238                 ax.apply_aspect()
#     239
#     240             for child in ax.get_children():
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\axes\_base.py in apply_aspect(self, position)
#    1893             box_aspect = aspect * self.get_data_ratio()
#    1894             pb = position.frozen()
# -> 1895             pb1 = pb.shrunk_to_aspect(box_aspect, pb, fig_aspect)
#    1896             self._set_position(pb1.anchored(self.get_anchor(), pb), 'active')
#    1897             return
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\matplotlib\transforms.py in shrunk_to_aspect(self, box_aspect, container, fig_aspect)
#     556         """
#     557         if box_aspect <= 0 or fig_aspect <= 0:
# --> 558             raise ValueError("'box_aspect' and 'fig_aspect' must be positive")
#     559         if container is None:
#     560             container = self
#
# ValueError: 'box_aspect' and 'fig_aspect' must be positive

# %%
from shpConverter import shp_to_csv

# %%
seoul_aou_shp_filepath = "./data/area_of_use/seoul_aou/seoul_aou_org.shp"
seoul_aou_shp_coordsys = "epsg:5174"
seoul_aou_gdf = gpd.read_file(seoul_aou_shp_filepath,encoding='utf-8')

# %%
saou_ax = seoul_aou_gdf.convex_hull.plot(color="green",edgecolor="w")
saou_ax.set_title("서울시 도시지역 공간정보")
saou_ax.set_axis_off() # 축제거
plt.show()
