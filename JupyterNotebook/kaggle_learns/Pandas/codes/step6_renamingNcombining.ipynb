# %%
import pandas as pd

# %%
reviews = pd.read_csv('../input/wine-reviews/winemag-data-130k-v2.csv',index_col=0)
reviews.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
reviews.rename(columns={'points':'score'},inplace=True)

# %%
reviews.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    score  price           province           region_1           region_2  \
# 0     87    NaN  Sicily & Sardinia               Etna                NaN
# 1     87   15.0              Douro                NaN                NaN
# 2     87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...

# %%
reviews=reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')

# %%
reviews.head(3)
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
#
# fields   designation  score  price           province           region_1  \
# wines
# 0       Vulkà Bianco     87    NaN  Sicily & Sardinia               Etna
# 1           Avidagos     87   15.0              Douro                NaN
# 2                NaN     87   14.0             Oregon  Willamette Valley
#
# fields           region_2    taster_name taster_twitter_handle  \
# wines
# 0                     NaN  Kerin O’Keefe          @kerinokeefe
# 1                     NaN     Roger Voss            @vossroger
# 2       Willamette Valley   Paul Gregutt           @paulgwine
#
# fields                                          title         variety  \
# wines
# ...

# %%
reviews.loc['wines1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\ITConsulting\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\ITConsulting\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'wines1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9064\4163253735.py in <module>
# ----> 1 reviews.loc['wines1']
#
# ...

# %%
# Create a DataFrame
data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}
df = pd.DataFrame(data)
# Assign names to row and column indexes
df = df.rename_axis('names', axis='rows').rename_axis('features', axis='columns')
df
# Out:
# features  A  B  C
# names
# 0         1  4  7
# 1         2  5  8
# 2         3  6  9

# %%
df.groupby('features',axis=1).sum()
# Out:
# features  A  B  C
# names
# 0         1  4  7
# 1         2  5  8
# 2         3  6  9

# %%
# df.at['names1','features1']

# %%
cy = pd.read_csv('../input/youtube-new/CAvideos.csv')
by = pd.read_csv('../input/youtube-new/GBvideos.csv')

# %%
pd.concat([cy,by],axis=1)
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...                                                  ...               ...
# ...

# %%
pd.concat([cy,by],axis=0)
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
len(cy.columns)
# Out:
# 16

# %%
# 1. set index
cysi = cy.set_index(['title','trending_date'])
bysi = by.set_index(['title','trending_date'])
# 2. combine two datasets which have same index
cb_join=cysi.join(bysi, lsuffix='_canada', rsuffix='_uk')
cb_join
# Out:
#                                                                  video_id_canada  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01          PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03          DvPW66IFhMI
# #1 Fortnite World Rank - 2,330 Solo Wins!          18.10.03          EXEaMjFeiEk
# #1 MOST ANTICIPATED VIDEO (Timber Frame House R... 17.20.12          bYvQmusLaxw
#                                                    17.21.12          bYvQmusLaxw
# ...                                                                          ...
# 😲She Is So Nervous But BLOWS The ROOF After Tak... 18.02.05          WttN1Z0XF4k
#                                                    18.29.04          WttN1Z0XF4k
#                                                    18.30.04          WttN1Z0XF4k
# 🚨 BREAKING NEWS 🔴 Raja Live all Slot Channels W... 18.07.05          Wt9Gkpmbt44
# ...

# %%
cb_join.video_id_canada.isnull().sum()
# Out:
# 0

# %%
cb_join.video_id_uk.isnull().sum()
# Out:
# 38730

# %%
len(cy)
# Out:
# 40881

# %%
len(by)
# Out:
# 38916

# %%
cb_leftjoin=cysi.join(bysi,how='left',lsuffix='_can',rsuffix='_uk')
cb_leftjoin
# Out:
#                                                                  video_id_can  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01       PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03       DvPW66IFhMI
# #1 Fortnite World Rank - 2,330 Solo Wins!          18.10.03       EXEaMjFeiEk
# #1 MOST ANTICIPATED VIDEO (Timber Frame House R... 17.20.12       bYvQmusLaxw
#                                                    17.21.12       bYvQmusLaxw
# ...                                                                       ...
# 😲She Is So Nervous But BLOWS The ROOF After Tak... 18.02.05       WttN1Z0XF4k
#                                                    18.29.04       WttN1Z0XF4k
#                                                    18.30.04       WttN1Z0XF4k
# 🚨 BREAKING NEWS 🔴 Raja Live all Slot Channels W... 18.07.05       Wt9Gkpmbt44
# ...

# %%
len(cb_leftjoin.index)
# Out:
# 40900

# %%
len(cysi.index)
# Out:
# 40881

# %%
members=pd.DataFrame({'id':[1,2,3],'name':['Paul','Peter','John']})
members
# Out:
#    id   name
# 0   1   Paul
# 1   2  Peter
# 2   3   John

# %%
phones = pd.DataFrame({'id':[1,2,3,3,3,4],'numbs':['010','011','022','023','024','044']})
phones
# Out:
#    id numbs
# 0   1   010
# 1   2   011
# 2   3   022
# 3   3   023
# 4   3   024
# 5   4   044

# %%
msi = members.set_index('id')
psi = phones.set_index('id')

# %%
left_join = msi.join(psi)
left_join
# Out:
#      name numbs
# id
# 1    Paul   010
# 2   Peter   011
# 3    John   022
# 3    John   023
# 3    John   024
